# %% [markdown]
# <a href="https://colab.research.google.com/github/HyunseokLee928/Fastcampus/blob/main/%5B%EC%8B%A4%EC%8A%B5%5DPart2_Ch02_%EC%9D%B4%EB%AF%B8%EC%A7%80_%EC%84%B8%EA%B7%B8%EB%A9%98%ED%85%8C%EC%9D%B4%EC%85%98_%EC%9D%B8%EB%AC%BC_%EC%82%AC%EC%A7%84%EC%97%90%EC%84%9C_%EB%B0%B0%EA%B2%BD_%EC%97%86%EC%95%A0%EA%B8%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 주제 : 사진에서 사람영역만 구분해보기
# --------------
# ## 실습 가이드
#     1. 데이터를 다운로드하여 Colab에 불러옵니다.
#     2. 필요한 라이브러리는 모두 코드로 작성되어 있습니다.
#     3. 코드는 위에서부터 아래로 순서대로 실행합니다.
#     4. 전체 문제 구성은 좌측 첫 번째 아이콘을 통해 확인할 수 있습니다.
#
# ## 데이터 소개
#     - 이번 주제의 데이터는 protrait 데이터로 유명한 PFCN dataset을 이용합니다.
#   ![PFCN dataset](https://www.researchgate.net/profile/Dawei_Li49/publication/334417334/figure/fig4/AS:832930272276492@1575597460956/Sample-images-from-the-PFCN-dataset.jpg)
#
#      위의 이미지는 다음과 같은 것을 보여줍니다.
#     - 800x600의 사람 portrait 이미지
#      - ?????.png
#     - 사람 영역에 대한 흑백 portrait 이미지
#      - ?????_matte.png
#     - pfcn_original
#      - 원본 800x600 이미지들
#     - pfcn_small
#      - colab용 100x75 이미지들
#
#
#
# - 데이터 출처:
#  - [PFCN dataset](https://1drv.ms/u/s!ApwdOxIIFBH19Ts5EuFd9gVJrKTo)
#  - [pfcn_small](https://drive.google.com/file/d/1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl/view?usp=sharing)
#  - [pfcn_original](https://onedrive.live.com/?authkey=%21ADkS4V32BUmspOg&cid=F5111408123B1D9C&id=F5111408123B1D9C%2115035&parId=F5111408123B1D9C%2115033&action=locate)
#
# ## 최종 목표
#
#     - 작게 줄인 PFCN 데이터를 이용하여 사람 영역 추출
#     - 코렙에 구글 drive 연동
#     - 큰 사진을 작게 줄이기
#     - 이미지에 대한 오토인코더식 접근 방법
#
# - 출제자 : 손근영 강사
# ---

# %%
import tensorflow as tf
from tensorflow import keras
from keras.layers import Dense
from keras.models import Sequential

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from IPython.display import Image

warnings.filterwarnings('ignore')
# %matplotlib inline

SEED = 34

# %% [markdown]
# ## Step 1. 도입전 기본 처리

# %% [markdown]
# ### 문제 1. 구글 drive와 colab 연동하기

# %%
# https://onedrive.live.com/?authkey=%21ADkS4V32BUmspOg&cid=F5111408123B1D9C&id=F5111408123B1D9C%2115035&parId=F5111408123B1D9C%2115033&action=locate

from google.colab import drive
drive.mount('/gdrive', force_remount=True)
# Out:
# Mounted at /gdrive

# %%
# !ls -al /gdrive/'My Drive'/'Colab Notebooks'/dataset/testing
# Out:
# total 186325
# -rw------- 1 root root   26653 Mar 15 06:28 00001_matte.png
# -rw------- 1 root root  753417 Mar 15 06:28 00001.png
# -rw------- 1 root root   34216 Mar 15 06:28 00002_matte.png
# -rw------- 1 root root  604936 Mar 15 06:28 00002.png
# -rw------- 1 root root   35363 Mar 15 06:28 00003_matte.png
# -rw------- 1 root root  435284 Mar 15 06:28 00003.png
# -rw------- 1 root root   28328 Mar 15 06:28 00004_matte.png
# -rw------- 1 root root  524318 Mar 15 06:28 00004.png
# -rw------- 1 root root   25115 Mar 15 06:28 00005_matte.png
# -rw------- 1 root root  540187 Mar 15 06:28 00005.png
# -rw------- 1 root root   31603 Mar 15 06:28 00006_matte.png
# -rw------- 1 root root  638427 Mar 15 06:28 00006.png
# -rw------- 1 root root   26514 Mar 15 06:28 00007_matte.png
# -rw------- 1 root root  655077 Mar 15 06:28 00007.png
# -rw------- 1 root root   39624 Mar 15 06:28 00008_matte.png
# -rw------- 1 root root  628124 Mar 15 06:28 00008.png
# -rw------- 1 root root   57820 Mar 15 06:28 00009_matte.png
# -rw------- 1 root root  679471 Mar 15 06:28 00009.png
# -rw------- 1 root root   32265 Mar 15 06:28 00010_matte.png
# -rw------- 1 root root  557970 Mar 15 06:28 00010.png
# -rw------- 1 root root   38379 Mar 15 06:28 00011_matte.png
# -rw------- 1 root root  379412 Mar 15 06:28 00011.png
# -rw------- 1 root root   20269 Mar 15 06:28 00012_matte.png
# -rw------- 1 root root  761756 Mar 15 06:28 00012.png
# -rw------- 1 root root   39359 Mar 15 06:28 00013_matte.png
# -rw------- 1 root root  646821 Mar 15 06:28 00013.png
# -rw------- 1 root root   28077 Mar 15 06:28 00014_matte.png
# -rw------- 1 root root  464003 Mar 15 06:28 00014.png
# -rw------- 1 root root   32580 Mar 15 06:28 00015_matte.png
# -rw------- 1 root root  441870 Mar 15 06:28 00015.png
# -rw------- 1 root root   38446 Mar 15 06:28 00016_matte.png
# -rw------- 1 root root  429587 Mar 15 06:28 00016.png
# -rw------- 1 root root   42726 Mar 15 06:28 00017_matte.png
# -rw------- 1 root root  745605 Mar 15 06:28 00017.png
# -rw------- 1 root root   24390 Mar 15 06:28 00018_matte.png
# -rw------- 1 root root  547359 Mar 15 06:28 00018.png
# -rw------- 1 root root   29989 Mar 15 06:28 00019_matte.png
# -rw------- 1 root root  633758 Mar 15 06:28 00019.png
# -rw------- 1 root root   31263 Mar 15 06:28 00020_matte.png
# -rw------- 1 root root  476458 Mar 15 06:28 00020.png
# -rw------- 1 root root   27503 Mar 15 06:28 00021_matte.png
# -rw------- 1 root root  577624 Mar 15 06:28 00021.png
# -rw------- 1 root root   23004 Mar 15 06:28 00022_matte.png
# -rw------- 1 root root  447274 Mar 15 06:28 00022.png
# -rw------- 1 root root   29802 Mar 15 06:28 00023_matte.png
# -rw------- 1 root root  492436 Mar 15 06:28 00023.png
# -rw------- 1 root root   32991 Mar 15 06:28 00024_matte.png
# -rw------- 1 root root  545456 Mar 15 06:28 00024.png
# -rw------- 1 root root   31110 Mar 15 06:28 00025_matte.png
# -rw------- 1 root root  608076 Mar 15 06:28 00025.png
# -rw------- 1 root root   41673 Mar 15 06:28 00026_matte.png
# -rw------- 1 root root  705137 Mar 15 06:28 00026.png
# -rw------- 1 root root   32096 Mar 15 06:28 00027_matte.png
# -rw------- 1 root root  645617 Mar 15 06:28 00027.png
# -rw------- 1 root root   32219 Mar 15 06:28 00028_matte.png
# -rw------- 1 root root  606461 Mar 15 06:28 00028.png
# -rw------- 1 root root   45482 Mar 15 06:28 00029_matte.png
# -rw------- 1 root root  494901 Mar 15 06:28 00029.png
# -rw------- 1 root root   30412 Mar 15 06:28 00030_matte.png
# -rw------- 1 root root  634398 Mar 15 06:28 00030.png
# -rw------- 1 root root   31266 Mar 15 06:28 00031_matte.png
# -rw------- 1 root root  901032 Mar 15 06:28 00031.png
# -rw------- 1 root root   31491 Mar 15 06:28 00032_matte.png
# -rw------- 1 root root  624173 Mar 15 06:28 00032.png
# -rw------- 1 root root   29427 Mar 15 06:28 00033_matte.png
# -rw------- 1 root root  311626 Mar 15 06:28 00033.png
# -rw------- 1 root root   40774 Mar 15 06:28 00034_matte.png
# -rw------- 1 root root  717204 Mar 15 06:28 00034.png
# -rw------- 1 root root   29399 Mar 15 06:28 00035_matte.png
# -rw------- 1 root root  602447 Mar 15 06:28 00035.png
# -rw------- 1 root root   14225 Mar 15 06:28 00036_matte.png
# -rw------- 1 root root  762827 Mar 15 06:28 00036.png
# -rw------- 1 root root   26703 Mar 15 06:28 00037_matte.png
# -rw------- 1 root root  550966 Mar 15 06:28 00037.png
# -rw------- 1 root root   23688 Mar 15 06:28 00038_matte.png
# -rw------- 1 root root  420617 Mar 15 06:28 00038.png
# -rw------- 1 root root   23044 Mar 15 06:28 00039_matte.png
# -rw------- 1 root root  642973 Mar 15 06:28 00039.png
# -rw------- 1 root root   33521 Mar 15 06:28 00040_matte.png
# -rw------- 1 root root  648059 Mar 15 06:28 00040.png
# -rw------- 1 root root   21696 Mar 15 06:28 00041_matte.png
# -rw------- 1 root root  537309 Mar 15 06:28 00041.png
# -rw------- 1 root root   40948 Mar 15 06:28 00042_matte.png
# -rw------- 1 root root  638497 Mar 15 06:28 00042.png
# -rw------- 1 root root   50001 Mar 15 06:28 00043_matte.png
# -rw------- 1 root root  610969 Mar 15 06:28 00043.png
# -rw------- 1 root root   30001 Mar 15 06:28 00044_matte.png
# -rw------- 1 root root  554991 Mar 15 06:28 00044.png
# -rw------- 1 root root   32284 Mar 15 06:28 00045_matte.png
# -rw------- 1 root root  784514 Mar 15 06:28 00045.png
# -rw------- 1 root root   23648 Mar 15 06:28 00046_matte.png
# -rw------- 1 root root  630038 Mar 15 06:28 00046.png
# -rw------- 1 root root   27102 Mar 15 06:28 00047_matte.png
# -rw------- 1 root root  572647 Mar 15 06:28 00047.png
# -rw------- 1 root root   30171 Mar 15 06:28 00048_matte.png
# -rw------- 1 root root  586623 Mar 15 06:28 00048.png
# -rw------- 1 root root   41990 Mar 15 06:28 00049_matte.png
# -rw------- 1 root root  626977 Mar 15 06:28 00049.png
# -rw------- 1 root root   34951 Mar 15 06:28 00050_matte.png
# -rw------- 1 root root  636561 Mar 15 06:28 00050.png
# -rw------- 1 root root   19389 Mar 15 06:28 00051_matte.png
# -rw------- 1 root root  720772 Mar 15 06:28 00051.png
# -rw------- 1 root root   32343 Mar 15 06:28 00052_matte.png
# -rw------- 1 root root  430006 Mar 15 06:28 00052.png
# -rw------- 1 root root   31053 Mar 15 06:28 00053_matte.png
# -rw------- 1 root root  499054 Mar 15 06:28 00053.png
# -rw------- 1 root root   45589 Mar 15 06:28 00054_matte.png
# -rw------- 1 root root  447406 Mar 15 06:28 00054.png
# -rw------- 1 root root   33644 Mar 15 06:28 00055_matte.png
# -rw------- 1 root root  746655 Mar 15 06:28 00055.png
# -rw------- 1 root root   33959 Mar 15 06:28 00056_matte.png
# -rw------- 1 root root  729899 Mar 15 06:28 00056.png
# -rw------- 1 root root   40091 Mar 15 06:28 00057_matte.png
# -rw------- 1 root root  865971 Mar 15 06:28 00057.png
# -rw------- 1 root root   24976 Mar 15 06:28 00058_matte.png
# -rw------- 1 root root  864516 Mar 15 06:28 00058.png
# -rw------- 1 root root   24738 Mar 15 06:28 00059_matte.png
# -rw------- 1 root root  463409 Mar 15 06:28 00059.png
# -rw------- 1 root root   31408 Mar 15 06:28 00060_matte.png
# -rw------- 1 root root  603261 Mar 15 06:28 00060.png
# -rw------- 1 root root   59940 Mar 15 06:28 00061_matte.png
# -rw------- 1 root root  784256 Mar 15 06:28 00061.png
# -rw------- 1 root root   31369 Mar 15 06:28 00062_matte.png
# -rw------- 1 root root  566323 Mar 15 06:28 00062.png
# -rw------- 1 root root   35496 Mar 15 06:28 00063_matte.png
# -rw------- 1 root root  431447 Mar 15 06:28 00063.png
# -rw------- 1 root root   41147 Mar 15 06:28 00064_matte.png
# -rw------- 1 root root  769012 Mar 15 06:28 00064.png
# -rw------- 1 root root   31652 Mar 15 06:28 00065_matte.png
# -rw------- 1 root root  969390 Mar 15 06:28 00065.png
# -rw------- 1 root root   28021 Mar 15 06:28 00066_matte.png
# -rw------- 1 root root  613150 Mar 15 06:28 00066.png
# -rw------- 1 root root   38557 Mar 15 06:28 00067_matte.png
# -rw------- 1 root root  671633 Mar 15 06:28 00067.png
# -rw------- 1 root root   32804 Mar 15 06:28 00068_matte.png
# -rw------- 1 root root  532692 Mar 15 06:28 00068.png
# -rw------- 1 root root   31625 Mar 15 06:28 00069_matte.png
# -rw------- 1 root root  601423 Mar 15 06:28 00069.png
# -rw------- 1 root root   33340 Mar 15 06:28 00070_matte.png
# -rw------- 1 root root  702202 Mar 15 06:28 00070.png
# -rw------- 1 root root   33292 Mar 15 06:28 00071_matte.png
# -rw------- 1 root root  685508 Mar 15 06:28 00071.png
# -rw------- 1 root root   28729 Mar 15 06:28 00072_matte.png
# -rw------- 1 root root  497152 Mar 15 06:28 00072.png
# -rw------- 1 root root   28970 Mar 15 06:28 00073_matte.png
# -rw------- 1 root root  709219 Mar 15 06:28 00073.png
# -rw------- 1 root root   21565 Mar 15 06:28 00074_matte.png
# -rw------- 1 root root  603503 Mar 15 06:28 00074.png
# -rw------- 1 root root   34364 Mar 15 06:28 00075_matte.png
# -rw------- 1 root root  617948 Mar 15 06:28 00075.png
# -rw------- 1 root root   27683 Mar 15 06:28 00076_matte.png
# -rw------- 1 root root  366475 Mar 15 06:28 00076.png
# -rw------- 1 root root   26099 Mar 15 06:28 00077_matte.png
# -rw------- 1 root root  525402 Mar 15 06:28 00077.png
# -rw------- 1 root root   26491 Mar 15 06:28 00078_matte.png
# -rw------- 1 root root  577951 Mar 15 06:28 00078.png
# -rw------- 1 root root   26713 Mar 15 06:28 00079_matte.png
# -rw------- 1 root root  579443 Mar 15 06:28 00079.png
# -rw------- 1 root root   24118 Mar 15 06:28 00080_matte.png
# -rw------- 1 root root  717387 Mar 15 06:28 00080.png
# -rw------- 1 root root   33510 Mar 15 06:28 00081_matte.png
# -rw------- 1 root root  553635 Mar 15 06:28 00081.png
# -rw------- 1 root root   33725 Mar 15 06:28 00082_matte.png
# -rw------- 1 root root  679002 Mar 15 06:28 00082.png
# -rw------- 1 root root   33318 Mar 15 06:28 00083_matte.png
# -rw------- 1 root root  493167 Mar 15 06:28 00083.png
# -rw------- 1 root root   30448 Mar 15 06:28 00084_matte.png
# -rw------- 1 root root  427149 Mar 15 06:28 00084.png
# -rw------- 1 root root   45299 Mar 15 06:28 00085_matte.png
# -rw------- 1 root root  786067 Mar 15 06:28 00085.png
# -rw------- 1 root root   28261 Mar 15 06:28 00086_matte.png
# -rw------- 1 root root  556408 Mar 15 06:28 00086.png
# -rw------- 1 root root   23158 Mar 15 06:28 00087_matte.png
# -rw------- 1 root root  641813 Mar 15 06:28 00087.png
# -rw------- 1 root root   31697 Mar 15 06:28 00088_matte.png
# -rw------- 1 root root  426599 Mar 15 06:28 00088.png
# -rw------- 1 root root   14330 Mar 15 06:28 00089_matte.png
# -rw------- 1 root root  659184 Mar 15 06:28 00089.png
# -rw------- 1 root root   33003 Mar 15 06:28 00090_matte.png
# -rw------- 1 root root  656642 Mar 15 06:28 00090.png
# -rw------- 1 root root   25699 Mar 15 06:28 00091_matte.png
# -rw------- 1 root root  589482 Mar 15 06:28 00091.png
# -rw------- 1 root root   47424 Mar 15 06:28 00092_matte.png
# -rw------- 1 root root  439907 Mar 15 06:28 00092.png
# -rw------- 1 root root   32705 Mar 15 06:28 00093_matte.png
# -rw------- 1 root root  747311 Mar 15 06:28 00093.png
# -rw------- 1 root root   31493 Mar 15 06:28 00094_matte.png
# -rw------- 1 root root  731284 Mar 15 06:28 00094.png
# -rw------- 1 root root   20641 Mar 15 06:28 00095_matte.png
# -rw------- 1 root root  559106 Mar 15 06:28 00095.png
# -rw------- 1 root root   59495 Mar 15 06:28 00096_matte.png
# -rw------- 1 root root  594604 Mar 15 06:28 00096.png
# -rw------- 1 root root   29540 Mar 15 06:28 00097_matte.png
# -rw------- 1 root root  620028 Mar 15 06:28 00097.png
# -rw------- 1 root root   30941 Mar 15 06:28 00098_matte.png
# -rw------- 1 root root  595124 Mar 15 06:28 00098.png
# -rw------- 1 root root   37839 Mar 15 06:28 00099_matte.png
# -rw------- 1 root root  884128 Mar 15 06:28 00099.png
# -rw------- 1 root root   37359 Mar 15 06:28 00100_matte.png
# -rw------- 1 root root  484485 Mar 15 06:28 00100.png
# -rw------- 1 root root   26945 Mar 15 06:28 00101_matte.png
# -rw------- 1 root root  707341 Mar 15 06:28 00101.png
# -rw------- 1 root root   43908 Mar 15 06:28 00102_matte.png
# -rw------- 1 root root  542251 Mar 15 06:28 00102.png
# -rw------- 1 root root   34364 Mar 15 06:28 00103_matte.png
# -rw------- 1 root root  848184 Mar 15 06:28 00103.png
# -rw------- 1 root root   29520 Mar 15 06:28 00104_matte.png
# -rw------- 1 root root  545517 Mar 15 06:28 00104.png
# -rw------- 1 root root   27742 Mar 15 06:28 00105_matte.png
# -rw------- 1 root root  632743 Mar 15 06:28 00105.png
# -rw------- 1 root root   31261 Mar 15 06:28 00106_matte.png
# -rw------- 1 root root  746093 Mar 15 06:28 00106.png
# -rw------- 1 root root   35519 Mar 15 06:28 00107_matte.png
# -rw------- 1 root root  458282 Mar 15 06:28 00107.png
# -rw------- 1 root root   51325 Mar 15 06:28 00108_matte.png
# -rw------- 1 root root  543029 Mar 15 06:28 00108.png
# -rw------- 1 root root   33139 Mar 15 06:28 00109_matte.png
# -rw------- 1 root root 1018171 Mar 15 06:28 00109.png
# -rw------- 1 root root   44994 Mar 15 06:28 00110_matte.png
# -rw------- 1 root root  727503 Mar 15 06:28 00110.png
# -rw------- 1 root root   31035 Mar 15 06:28 00111_matte.png
# -rw------- 1 root root  461946 Mar 15 06:28 00111.png
# -rw------- 1 root root   30755 Mar 15 06:28 00112_matte.png
# -rw------- 1 root root  588147 Mar 15 06:28 00112.png
# -rw------- 1 root root   25281 Mar 15 06:28 00113_matte.png
# -rw------- 1 root root  397195 Mar 15 06:28 00113.png
# -rw------- 1 root root   28326 Mar 15 06:28 00114_matte.png
# -rw------- 1 root root  337996 Mar 15 06:28 00114.png
# -rw------- 1 root root   45761 Mar 15 06:28 00115_matte.png
# -rw------- 1 root root  736098 Mar 15 06:28 00115.png
# -rw------- 1 root root   29541 Mar 15 06:28 00116_matte.png
# -rw------- 1 root root  562667 Mar 15 06:28 00116.png
# -rw------- 1 root root   27376 Mar 15 06:28 00117_matte.png
# -rw------- 1 root root  467440 Mar 15 06:28 00117.png
# -rw------- 1 root root   30363 Mar 15 06:28 00118_matte.png
# -rw------- 1 root root  617738 Mar 15 06:28 00118.png
# -rw------- 1 root root   28270 Mar 15 06:28 00119_matte.png
# -rw------- 1 root root  467434 Mar 15 06:28 00119.png
# -rw------- 1 root root   28523 Mar 15 06:28 00120_matte.png
# -rw------- 1 root root  498939 Mar 15 06:28 00120.png
# -rw------- 1 root root   33090 Mar 15 06:28 00121_matte.png
# -rw------- 1 root root  552375 Mar 15 06:28 00121.png
# -rw------- 1 root root   28653 Mar 15 06:28 00122_matte.png
# -rw------- 1 root root  743832 Mar 15 06:28 00122.png
# -rw------- 1 root root   17883 Mar 15 06:28 00123_matte.png
# -rw------- 1 root root  736206 Mar 15 06:28 00123.png
# -rw------- 1 root root   29640 Mar 15 06:28 00124_matte.png
# -rw------- 1 root root  555223 Mar 15 06:28 00124.png
# -rw------- 1 root root   30941 Mar 15 06:28 00125_matte.png
# -rw------- 1 root root  592012 Mar 15 06:28 00125.png
# -rw------- 1 root root   36649 Mar 15 06:28 00126_matte.png
# -rw------- 1 root root  858994 Mar 15 06:28 00126.png
# -rw------- 1 root root   34948 Mar 15 06:28 00127_matte.png
# -rw------- 1 root root  656681 Mar 15 06:28 00127.png
# -rw------- 1 root root   33693 Mar 15 06:28 00128_matte.png
# -rw------- 1 root root  975749 Mar 15 06:28 00128.png
# -rw------- 1 root root   29262 Mar 15 06:28 00129_matte.png
# -rw------- 1 root root  501401 Mar 15 06:28 00129.png
# -rw------- 1 root root   25846 Mar 15 06:28 00130_matte.png
# -rw------- 1 root root  770479 Mar 15 06:28 00130.png
# -rw------- 1 root root   33251 Mar 15 06:28 00131_matte.png
# -rw------- 1 root root  675770 Mar 15 06:28 00131.png
# -rw------- 1 root root   29985 Mar 15 06:28 00132_matte.png
# -rw------- 1 root root  791558 Mar 15 06:28 00132.png
# -rw------- 1 root root   30182 Mar 15 06:28 00133_matte.png
# -rw------- 1 root root  681012 Mar 15 06:28 00133.png
# -rw------- 1 root root   23828 Mar 15 06:28 00134_matte.png
# -rw------- 1 root root  431676 Mar 15 06:28 00134.png
# -rw------- 1 root root   31620 Mar 15 06:28 00135_matte.png
# -rw------- 1 root root  513229 Mar 15 06:28 00135.png
# -rw------- 1 root root   28588 Mar 15 06:28 00136_matte.png
# -rw------- 1 root root  609718 Mar 15 06:28 00136.png
# -rw------- 1 root root   26987 Mar 15 06:28 00137_matte.png
# -rw------- 1 root root  523392 Mar 15 06:28 00137.png
# -rw------- 1 root root   25916 Mar 15 06:28 00138_matte.png
# -rw------- 1 root root  381775 Mar 15 06:28 00138.png
# -rw------- 1 root root   31244 Mar 15 06:28 00139_matte.png
# -rw------- 1 root root  662584 Mar 15 06:28 00139.png
# -rw------- 1 root root   30078 Mar 15 06:28 00140_matte.png
# -rw------- 1 root root  556793 Mar 15 06:28 00140.png
# -rw------- 1 root root   30555 Mar 15 06:28 00141_matte.png
# -rw------- 1 root root  588647 Mar 15 06:28 00141.png
# -rw------- 1 root root   29536 Mar 15 06:28 00142_matte.png
# -rw------- 1 root root  765101 Mar 15 06:28 00142.png
# -rw------- 1 root root   38094 Mar 15 06:28 00143_matte.png
# -rw------- 1 root root  828953 Mar 15 06:28 00143.png
# -rw------- 1 root root   29035 Mar 15 06:28 00144_matte.png
# -rw------- 1 root root  514683 Mar 15 06:28 00144.png
# -rw------- 1 root root   30773 Mar 15 06:28 00145_matte.png
# -rw------- 1 root root  725326 Mar 15 06:28 00145.png
# -rw------- 1 root root   34425 Mar 15 06:28 00146_matte.png
# -rw------- 1 root root  653280 Mar 15 06:28 00146.png
# -rw------- 1 root root   27942 Mar 15 06:28 00147_matte.png
# -rw------- 1 root root  476146 Mar 15 06:28 00147.png
# -rw------- 1 root root   23608 Mar 15 06:28 00148_matte.png
# -rw------- 1 root root  529230 Mar 15 06:28 00148.png
# -rw------- 1 root root   25826 Mar 15 06:28 00149_matte.png
# -rw------- 1 root root  757631 Mar 15 06:28 00149.png
# -rw------- 1 root root   35782 Mar 15 06:28 00150_matte.png
# -rw------- 1 root root  654349 Mar 15 06:28 00150.png
# -rw------- 1 root root   26412 Mar 15 06:28 00151_matte.png
# -rw------- 1 root root  594475 Mar 15 06:28 00151.png
# -rw------- 1 root root   26988 Mar 15 06:28 00152_matte.png
# -rw------- 1 root root  698116 Mar 15 06:28 00152.png
# -rw------- 1 root root   28752 Mar 15 06:28 00153_matte.png
# -rw------- 1 root root  319224 Mar 15 06:28 00153.png
# -rw------- 1 root root   30361 Mar 15 06:28 00154_matte.png
# -rw------- 1 root root  707311 Mar 15 06:28 00154.png
# -rw------- 1 root root   24597 Mar 15 06:28 00155_matte.png
# -rw------- 1 root root  519155 Mar 15 06:28 00155.png
# -rw------- 1 root root   31746 Mar 15 06:28 00156_matte.png
# -rw------- 1 root root  737597 Mar 15 06:28 00156.png
# -rw------- 1 root root   31136 Mar 15 06:28 00157_matte.png
# -rw------- 1 root root  482965 Mar 15 06:28 00157.png
# -rw------- 1 root root   36365 Mar 15 06:28 00158_matte.png
# -rw------- 1 root root  718630 Mar 15 06:28 00158.png
# -rw------- 1 root root   28556 Mar 15 06:28 00159_matte.png
# -rw------- 1 root root  591547 Mar 15 06:28 00159.png
# -rw------- 1 root root   28063 Mar 15 06:28 00160_matte.png
# -rw------- 1 root root  445317 Mar 15 06:28 00160.png
# -rw------- 1 root root   27939 Mar 15 06:28 00161_matte.png
# -rw------- 1 root root  756322 Mar 15 06:28 00161.png
# -rw------- 1 root root   36804 Mar 15 06:28 00162_matte.png
# -rw------- 1 root root  605337 Mar 15 06:28 00162.png
# -rw------- 1 root root   31478 Mar 15 06:28 00163_matte.png
# -rw------- 1 root root  698096 Mar 15 06:28 00163.png
# -rw------- 1 root root   31615 Mar 15 06:28 00164_matte.png
# -rw------- 1 root root  759154 Mar 15 06:28 00164.png
# -rw------- 1 root root   29395 Mar 15 06:28 00165_matte.png
# -rw------- 1 root root  617927 Mar 15 06:28 00165.png
# -rw------- 1 root root   33682 Mar 15 06:28 00166_matte.png
# -rw------- 1 root root  521272 Mar 15 06:28 00166.png
# -rw------- 1 root root   33110 Mar 15 06:28 00167_matte.png
# -rw------- 1 root root  700109 Mar 15 06:28 00167.png
# -rw------- 1 root root   43643 Mar 15 06:28 00168_matte.png
# -rw------- 1 root root  615555 Mar 15 06:28 00168.png
# -rw------- 1 root root   34737 Mar 15 06:28 00169_matte.png
# -rw------- 1 root root  780643 Mar 15 06:28 00169.png
# -rw------- 1 root root   29244 Mar 15 06:28 00170_matte.png
# -rw------- 1 root root  450260 Mar 15 06:28 00170.png
# -rw------- 1 root root   29346 Mar 15 06:28 00171_matte.png
# -rw------- 1 root root  421789 Mar 15 06:28 00171.png
# -rw------- 1 root root   37684 Mar 15 06:28 00172_matte.png
# -rw------- 1 root root  591547 Mar 15 06:28 00172.png
# -rw------- 1 root root   34916 Mar 15 06:28 00173_matte.png
# -rw------- 1 root root  657263 Mar 15 06:28 00173.png
# -rw------- 1 root root   28749 Mar 15 06:28 00174_matte.png
# -rw------- 1 root root  617619 Mar 15 06:28 00174.png
# -rw------- 1 root root   24291 Mar 15 06:28 00175_matte.png
# -rw------- 1 root root  727260 Mar 15 06:28 00175.png
# -rw------- 1 root root   31817 Mar 15 06:28 00176_matte.png
# -rw------- 1 root root  699420 Mar 15 06:28 00176.png
# -rw------- 1 root root   26947 Mar 15 06:28 00177_matte.png
# -rw------- 1 root root  317697 Mar 15 06:28 00177.png
# -rw------- 1 root root   27649 Mar 15 06:28 00178_matte.png
# -rw------- 1 root root  674841 Mar 15 06:28 00178.png
# -rw------- 1 root root   33560 Mar 15 06:28 00179_matte.png
# -rw------- 1 root root  587288 Mar 15 06:28 00179.png
# -rw------- 1 root root   36218 Mar 15 06:28 00180_matte.png
# -rw------- 1 root root  647130 Mar 15 06:28 00180.png
# -rw------- 1 root root   30378 Mar 15 06:28 00181_matte.png
# -rw------- 1 root root  632325 Mar 15 06:28 00181.png
# -rw------- 1 root root   30287 Mar 15 06:28 00182_matte.png
# -rw------- 1 root root  690799 Mar 15 06:28 00182.png
# -rw------- 1 root root   22415 Mar 15 06:28 00183_matte.png
# -rw------- 1 root root  604699 Mar 15 06:28 00183.png
# -rw------- 1 root root   33066 Mar 15 06:28 00184_matte.png
# -rw------- 1 root root  679221 Mar 15 06:28 00184.png
# -rw------- 1 root root   32597 Mar 15 06:28 00185_matte.png
# -rw------- 1 root root  659299 Mar 15 06:28 00185.png
# -rw------- 1 root root   30953 Mar 15 06:28 00186_matte.png
# -rw------- 1 root root  540142 Mar 15 06:28 00186.png
# -rw------- 1 root root   25420 Mar 15 06:28 00187_matte.png
# -rw------- 1 root root  639751 Mar 15 06:28 00187.png
# -rw------- 1 root root   36958 Mar 15 06:28 00188_matte.png
# -rw------- 1 root root  861443 Mar 15 06:28 00188.png
# -rw------- 1 root root   33564 Mar 15 06:28 00189_matte.png
# -rw------- 1 root root  646336 Mar 15 06:28 00189.png
# -rw------- 1 root root   31013 Mar 15 06:28 00190_matte.png
# -rw------- 1 root root  655693 Mar 15 06:28 00190.png
# -rw------- 1 root root   23860 Mar 15 06:28 00191_matte.png
# -rw------- 1 root root  528489 Mar 15 06:28 00191.png
# -rw------- 1 root root   35175 Mar 15 06:28 00192_matte.png
# -rw------- 1 root root  686556 Mar 15 06:28 00192.png
# -rw------- 1 root root   28912 Mar 15 06:28 00193_matte.png
# -rw------- 1 root root  614075 Mar 15 06:28 00193.png
# -rw------- 1 root root   29323 Mar 15 06:28 00194_matte.png
# -rw------- 1 root root  553983 Mar 15 06:28 00194.png
# -rw------- 1 root root   30815 Mar 15 06:28 00195_matte.png
# -rw------- 1 root root  526919 Mar 15 06:28 00195.png
# -rw------- 1 root root   27804 Mar 15 06:28 00196_matte.png
# -rw------- 1 root root  547014 Mar 15 06:28 00196.png
# -rw------- 1 root root   31006 Mar 15 06:28 00197_matte.png
# -rw------- 1 root root  590618 Mar 15 06:28 00197.png
# -rw------- 1 root root   30048 Mar 15 06:28 00198_matte.png
# -rw------- 1 root root  772332 Mar 15 06:28 00198.png
# -rw------- 1 root root   27843 Mar 15 06:28 00199_matte.png
# -rw------- 1 root root  654960 Mar 15 06:28 00199.png
# -rw------- 1 root root   43540 Mar 15 06:28 00200_matte.png
# -rw------- 1 root root  689422 Mar 15 06:28 00200.png
# -rw------- 1 root root   40174 Mar 15 06:28 00201_matte.png
# -rw------- 1 root root  256611 Mar 15 06:28 00201.png
# -rw------- 1 root root   34054 Mar 15 06:28 00202_matte.png
# -rw------- 1 root root  783182 Mar 15 06:28 00202.png
# -rw------- 1 root root   28981 Mar 15 06:28 00203_matte.png
# -rw------- 1 root root  437345 Mar 15 06:28 00203.png
# -rw------- 1 root root   27311 Mar 15 06:28 00204_matte.png
# -rw------- 1 root root  557341 Mar 15 06:28 00204.png
# -rw------- 1 root root   28034 Mar 15 06:28 00205_matte.png
# -rw------- 1 root root  578261 Mar 15 06:28 00205.png
# -rw------- 1 root root   28721 Mar 15 06:28 00206_matte.png
# -rw------- 1 root root  428798 Mar 15 06:28 00206.png
# -rw------- 1 root root   23609 Mar 15 06:28 00207_matte.png
# -rw------- 1 root root  495236 Mar 15 06:28 00207.png
# -rw------- 1 root root   42315 Mar 15 06:28 00208_matte.png
# -rw------- 1 root root  238513 Mar 15 06:28 00208.png
# -rw------- 1 root root   26886 Mar 15 06:28 00209_matte.png
# -rw------- 1 root root  548973 Mar 15 06:28 00209.png
# -rw------- 1 root root   37661 Mar 15 06:28 00210_matte.png
# -rw------- 1 root root  310427 Mar 15 06:28 00210.png
# -rw------- 1 root root   23246 Mar 15 06:28 00211_matte.png
# -rw------- 1 root root  559332 Mar 15 06:28 00211.png
# -rw------- 1 root root   30450 Mar 15 06:28 00212_matte.png
# -rw------- 1 root root  580053 Mar 15 06:28 00212.png
# -rw------- 1 root root   14138 Mar 15 06:28 00213_matte.png
# -rw------- 1 root root  628653 Mar 15 06:28 00213.png
# -rw------- 1 root root   32347 Mar 15 06:28 00214_matte.png
# -rw------- 1 root root  506834 Mar 15 06:28 00214.png
# -rw------- 1 root root   35500 Mar 15 06:28 00215_matte.png
# -rw------- 1 root root  554285 Mar 15 06:28 00215.png
# -rw------- 1 root root   27682 Mar 15 06:28 00216_matte.png
# -rw------- 1 root root  625423 Mar 15 06:28 00216.png
# -rw------- 1 root root   38207 Mar 15 06:28 00217_matte.png
# -rw------- 1 root root  463017 Mar 15 06:28 00217.png
# -rw------- 1 root root   32747 Mar 15 06:28 00218_matte.png
# -rw------- 1 root root  448248 Mar 15 06:28 00218.png
# -rw------- 1 root root   29552 Mar 15 06:28 00219_matte.png
# -rw------- 1 root root  544361 Mar 15 06:28 00219.png
# -rw------- 1 root root   31029 Mar 15 06:28 00220_matte.png
# -rw------- 1 root root  601763 Mar 15 06:28 00220.png
# -rw------- 1 root root   28168 Mar 15 06:28 00221_matte.png
# -rw------- 1 root root  718552 Mar 15 06:28 00221.png
# -rw------- 1 root root   44775 Mar 15 06:28 00222_matte.png
# -rw------- 1 root root  662834 Mar 15 06:28 00222.png
# -rw------- 1 root root   33051 Mar 15 06:28 00223_matte.png
# -rw------- 1 root root  600700 Mar 15 06:28 00223.png
# -rw------- 1 root root   35441 Mar 15 06:28 00224_matte.png
# -rw------- 1 root root  499639 Mar 15 06:28 00224.png
# -rw------- 1 root root   25957 Mar 15 06:28 00225_matte.png
# -rw------- 1 root root  771901 Mar 15 06:28 00225.png
# -rw------- 1 root root   31112 Mar 15 06:28 00226_matte.png
# -rw------- 1 root root  528935 Mar 15 06:28 00226.png
# -rw------- 1 root root   22903 Mar 15 06:28 00227_matte.png
# -rw------- 1 root root  524399 Mar 15 06:28 00227.png
# -rw------- 1 root root   41041 Mar 15 06:28 00228_matte.png
# -rw------- 1 root root  715623 Mar 15 06:28 00228.png
# -rw------- 1 root root   31118 Mar 15 06:28 00229_matte.png
# -rw------- 1 root root  727501 Mar 15 06:28 00229.png
# -rw------- 1 root root   28011 Mar 15 06:28 00230_matte.png
# -rw------- 1 root root  419499 Mar 15 06:28 00230.png
# -rw------- 1 root root   24337 Mar 15 06:28 00231_matte.png
# -rw------- 1 root root  571338 Mar 15 06:28 00231.png
# -rw------- 1 root root   32094 Mar 15 06:28 00232_matte.png
# -rw------- 1 root root  641484 Mar 15 06:28 00232.png
# -rw------- 1 root root   44632 Mar 15 06:28 00233_matte.png
# -rw------- 1 root root  443967 Mar 15 06:28 00233.png
# -rw------- 1 root root   28349 Mar 15 06:28 00234_matte.png
# -rw------- 1 root root  675843 Mar 15 06:28 00234.png
# -rw------- 1 root root   39331 Mar 15 06:28 00235_matte.png
# -rw------- 1 root root  468029 Mar 15 06:28 00235.png
# -rw------- 1 root root   51816 Mar 15 06:28 00236_matte.png
# -rw------- 1 root root  717474 Mar 15 06:28 00236.png
# -rw------- 1 root root   39580 Mar 15 06:28 00237_matte.png
# -rw------- 1 root root  510228 Mar 15 06:28 00237.png
# -rw------- 1 root root   32776 Mar 15 06:28 00238_matte.png
# -rw------- 1 root root  526049 Mar 15 06:28 00238.png
# -rw------- 1 root root   39447 Mar 15 06:28 00239_matte.png
# -rw------- 1 root root  412914 Mar 15 06:28 00239.png
# -rw------- 1 root root   45337 Mar 15 06:28 00240_matte.png
# -rw------- 1 root root  526811 Mar 15 06:28 00240.png
# -rw------- 1 root root   43967 Mar 15 06:28 00241_matte.png
# -rw------- 1 root root  419106 Mar 15 06:28 00241.png
# -rw------- 1 root root   32213 Mar 15 06:28 00242_matte.png
# -rw------- 1 root root  799674 Mar 15 06:28 00242.png
# -rw------- 1 root root   41895 Mar 15 06:28 00243_matte.png
# -rw------- 1 root root  684877 Mar 15 06:28 00243.png
# -rw------- 1 root root   19660 Mar 15 06:28 00244_matte.png
# -rw------- 1 root root  525039 Mar 15 06:28 00244.png
# -rw------- 1 root root   51632 Mar 15 06:28 00245_matte.png
# -rw------- 1 root root  478399 Mar 15 06:28 00245.png
# -rw------- 1 root root   26944 Mar 15 06:28 00246_matte.png
# -rw------- 1 root root  458173 Mar 15 06:28 00246.png
# -rw------- 1 root root   68436 Mar 15 06:28 00247_matte.png
# -rw------- 1 root root  595788 Mar 15 06:28 00247.png
# -rw------- 1 root root   59661 Mar 15 06:28 00248_matte.png
# -rw------- 1 root root  617317 Mar 15 06:28 00248.png
# -rw------- 1 root root   36314 Mar 15 06:28 00249_matte.png
# -rw------- 1 root root  497897 Mar 15 06:28 00249.png
# -rw------- 1 root root   52017 Mar 15 06:28 00250_matte.png
# -rw------- 1 root root  569223 Mar 15 06:28 00250.png
# -rw------- 1 root root   43026 Mar 15 06:29 00251_matte.png
# -rw------- 1 root root  637960 Mar 15 06:29 00251.png
# -rw------- 1 root root   30233 Mar 15 06:29 00252_matte.png
# -rw------- 1 root root  575121 Mar 15 06:29 00252.png
# -rw------- 1 root root   40141 Mar 15 06:29 00253_matte.png
# -rw------- 1 root root  559458 Mar 15 06:29 00253.png
# -rw------- 1 root root   49282 Mar 15 06:29 00254_matte.png
# -rw------- 1 root root  515655 Mar 15 06:29 00254.png
# -rw------- 1 root root   28992 Mar 15 06:29 00255_matte.png
# -rw------- 1 root root  568896 Mar 15 06:29 00255.png
# -rw------- 1 root root   41000 Mar 15 06:29 00256_matte.png
# -rw------- 1 root root  447659 Mar 15 06:29 00256.png
# -rw------- 1 root root   32613 Mar 15 06:29 00257_matte.png
# -rw------- 1 root root  540825 Mar 15 06:29 00257.png
# -rw------- 1 root root   20278 Mar 15 06:29 00258_matte.png
# -rw------- 1 root root  495523 Mar 15 06:29 00258.png
# -rw------- 1 root root   25348 Mar 15 06:29 00259_matte.png
# -rw------- 1 root root  707971 Mar 15 06:29 00259.png
# -rw------- 1 root root   38452 Mar 15 06:29 00260_matte.png
# -rw------- 1 root root  691180 Mar 15 06:29 00260.png
# -rw------- 1 root root   43181 Mar 15 06:29 00261_matte.png
# -rw------- 1 root root  553864 Mar 15 06:29 00261.png
# -rw------- 1 root root   26579 Mar 15 06:29 00262_matte.png
# -rw------- 1 root root  578850 Mar 15 06:29 00262.png
# -rw------- 1 root root   24670 Mar 15 06:29 00263_matte.png
# -rw------- 1 root root  729106 Mar 15 06:29 00263.png
# -rw------- 1 root root   22221 Mar 15 06:29 00264_matte.png
# -rw------- 1 root root  557074 Mar 15 06:29 00264.png
# -rw------- 1 root root   23417 Mar 15 06:29 00265_matte.png
# -rw------- 1 root root  978992 Mar 15 06:29 00265.png
# -rw------- 1 root root   28153 Mar 15 06:29 00266_matte.png
# -rw------- 1 root root  722367 Mar 15 06:29 00266.png
# -rw------- 1 root root   42029 Mar 15 06:29 00267_matte.png
# -rw------- 1 root root  460573 Mar 15 06:29 00267.png
# -rw------- 1 root root   41961 Mar 15 06:29 00268_matte.png
# -rw------- 1 root root  762130 Mar 15 06:29 00268.png
# -rw------- 1 root root   51466 Mar 15 06:29 00269_matte.png
# -rw------- 1 root root  570491 Mar 15 06:29 00269.png
# -rw------- 1 root root   41800 Mar 15 06:29 00270_matte.png
# -rw------- 1 root root  529093 Mar 15 06:29 00270.png
# -rw------- 1 root root   97083 Mar 15 06:29 00271_matte.png
# -rw------- 1 root root  702342 Mar 15 06:29 00271.png
# -rw------- 1 root root   47010 Mar 15 06:29 00272_matte.png
# -rw------- 1 root root  556550 Mar 15 06:29 00272.png
# -rw------- 1 root root   30514 Mar 15 06:29 00273_matte.png
# -rw------- 1 root root  685971 Mar 15 06:29 00273.png
# -rw------- 1 root root   36173 Mar 15 06:29 00274_matte.png
# -rw------- 1 root root  717552 Mar 15 06:29 00274.png
# -rw------- 1 root root   45937 Mar 15 06:29 00275_matte.png
# -rw------- 1 root root  512312 Mar 15 06:29 00275.png
# -rw------- 1 root root   31479 Mar 15 06:29 00276_matte.png
# -rw------- 1 root root  496292 Mar 15 06:29 00276.png
# -rw------- 1 root root   37854 Mar 15 06:29 00277_matte.png
# -rw------- 1 root root  624105 Mar 15 06:29 00277.png
# -rw------- 1 root root   37169 Mar 15 06:29 00278_matte.png
# -rw------- 1 root root  491152 Mar 15 06:29 00278.png
# -rw------- 1 root root   33869 Mar 15 06:29 00279_matte.png
# -rw------- 1 root root  727764 Mar 15 06:29 00279.png
# -rw------- 1 root root   28046 Mar 15 06:29 00280_matte.png
# -rw------- 1 root root  557857 Mar 15 06:29 00280.png
# -rw------- 1 root root   35640 Mar 15 06:29 00281_matte.png
# -rw------- 1 root root  612285 Mar 15 06:29 00281.png
# -rw------- 1 root root   48320 Mar 15 06:29 00282_matte.png
# -rw------- 1 root root  580388 Mar 15 06:29 00282.png
# -rw------- 1 root root   27265 Mar 15 06:29 00283_matte.png
# -rw------- 1 root root  544296 Mar 15 06:29 00283.png
# -rw------- 1 root root   28121 Mar 15 06:29 00284_matte.png
# -rw------- 1 root root  621826 Mar 15 06:29 00284.png
# -rw------- 1 root root   31375 Mar 15 06:29 00285_matte.png
# -rw------- 1 root root  476982 Mar 15 06:29 00285.png
# -rw------- 1 root root   45730 Mar 15 06:29 00286_matte.png
# -rw------- 1 root root  661364 Mar 15 06:29 00286.png
# -rw------- 1 root root   26416 Mar 15 06:29 00287_matte.png
# -rw------- 1 root root  848084 Mar 15 06:29 00287.png
# -rw------- 1 root root   61232 Mar 15 06:29 00288_matte.png
# -rw------- 1 root root  619399 Mar 15 06:29 00288.png
# -rw------- 1 root root   60144 Mar 15 06:29 00289_matte.png
# -rw------- 1 root root  582055 Mar 15 06:29 00289.png
# -rw------- 1 root root   23660 Mar 15 06:29 00290_matte.png
# -rw------- 1 root root  481500 Mar 15 06:29 00290.png
# -rw------- 1 root root   51908 Mar 15 06:29 00291_matte.png
# -rw------- 1 root root  552728 Mar 15 06:29 00291.png
# -rw------- 1 root root   42566 Mar 15 06:29 00292_matte.png
# -rw------- 1 root root  533282 Mar 15 06:29 00292.png
# -rw------- 1 root root   88116 Mar 15 06:29 00293_matte.png
# -rw------- 1 root root  621465 Mar 15 06:29 00293.png
# -rw------- 1 root root   44305 Mar 15 06:29 00294_matte.png
# -rw------- 1 root root  492551 Mar 15 06:29 00294.png
# -rw------- 1 root root   33687 Mar 15 06:29 00295_matte.png
# -rw------- 1 root root  575760 Mar 15 06:29 00295.png
# -rw------- 1 root root   38603 Mar 15 06:29 00296_matte.png
# -rw------- 1 root root  553879 Mar 15 06:29 00296.png
# -rw------- 1 root root   43928 Mar 15 06:29 00297_matte.png
# -rw------- 1 root root  646161 Mar 15 06:29 00297.png
# -rw------- 1 root root   43808 Mar 15 06:29 00298_matte.png
# -rw------- 1 root root  636810 Mar 15 06:29 00298.png
# -rw------- 1 root root   47819 Mar 15 06:29 00299_matte.png
# -rw------- 1 root root  770714 Mar 15 06:29 00299.png
# -rw------- 1 root root   34922 Mar 15 06:29 00300_matte.png
# -rw------- 1 root root  575126 Mar 15 06:29 00300.png

# %% [markdown]
# ### 문제 2. pfcn 데이터 살펴보기

# %%
# 데이터를 np array로 training에서 사람 이미지 한장과 영역 이미지 한장을 불러오는 코드를 작성해주세요. (x, y로 변수 대입)
import glob
import imageio

x = imageio.imread('/gdrive/My Drive/Colab Notebooks/dataset/training/00002.png')
y = imageio.imread('/gdrive/My Drive/Colab Notebooks/dataset/training/00002_matte.png')

# %%
a = imageio.imread('/gdrive/My Drive/Colab Notebooks/dataset/texture.jpg')
plt.imshow(a)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1380/2688896635.py in <cell line: 0>()
# ----> 1 a = imageio.imread('/gdrive/My Drive/Colab Notebooks/dataset/texture.jpg')
#       2 plt.imshow(a)
#       3 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/imageio/__init__.py in imread(uri, format, **kwargs)
#      98     )
#      99
# --> 100     return imread_v2(uri, format=format, **kwargs)
#     101
#     102
#
# /usr/local/lib/python3.12/dist-packages/imageio/v2.py in imread(uri, format, **kwargs)
#     357     imopen_args["legacy_mode"] = True
#     358
# --> 359     with imopen(uri, "ri", **imopen_args) as file:
#     360         result = file.read(index=0, **kwargs)
#     361
#
# /usr/local/lib/python3.12/dist-packages/imageio/core/imopen.py in imopen(uri, io_mode, plugin, extension, format_hint, legacy_mode, **kwargs)
#     111         request.format_hint = format_hint
#     112     else:
# --> 113         request = Request(uri, io_mode, format_hint=format_hint, extension=extension)
#     114
#     115     source = "<bytes>" if isinstance(uri, bytes) else uri
#
# /usr/local/lib/python3.12/dist-packages/imageio/core/request.py in __init__(self, uri, mode, extension, format_hint, **kwargs)
#     248
#     249         # Parse what was given
# --> 250         self._parse_uri(uri)
#     251
#     252         # Set extension
#
# /usr/local/lib/python3.12/dist-packages/imageio/core/request.py in _parse_uri(self, uri)
#     408                 # Reading: check that the file exists (but is allowed a dir)
#     409                 if not os.path.exists(fn):
# --> 410                     raise FileNotFoundError("No such file: '%s'" % fn)
#     411             else:
#     412                 # Writing: check that the directory to write to does exist
#
# FileNotFoundError: No such file: '/gdrive/My Drive/Colab Notebooks/dataset/texture.jpg'

# %% [markdown]
# ### 문제 3. x와 y의 shape을 출력해보세요.

# %%
# 데이터의 크기를 shape 함수를 통해 출력해주세요.
print(x.shape)
print(y.shape)
# Out:
# (800, 600, 3)
# (800, 600)

# %% [markdown]
# ### 문제 4. x, y를 각각 plt를 통하여 출력하세요.

# %%
# x, y를 plt를 이용하여 출력하는 코드를 작성해보세요.
plt.imshow(x)
plt.colorbar()
plt.show()
plt.imshow(y)
plt.colorbar()
plt.show()

# %% [markdown]
# ### 문제 5. (800, 600)의 의미지는 colab에서 돌리기에 너무 큽니다. (100, 75)로 이미지를 줄여보세요

# %%
# x와 y를 각각 (800, 600, 3) -> (100, 75, 3), (800, 600) -> (100, 75)로 줄이고 plt에서 확인하는 코드를 작성하세요.
from skimage.transform import resize
x1 = resize(x, (100, 75))
y1 = resize(y, (100, 75))

# %%
x1.shape, y1.shape
# Out:
# ((100, 75, 3), (100, 75))

# %% [markdown]
# ### 문제 6 pfcn_small.npz 데이터에서 학습, 테스트 데이터를 로드하세요.

# %%
# 주어진 링크에서 pfcn_small.npz를 다운 받으세요.
#https://drive.google.com/file/d/1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl/view?usp=sharing

# !gdown --id 1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl
# Out:
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:139: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl
# From (redirected): https://drive.google.com/uc?id=1_q37TRIFwtwhmSeLu_4h3SkFHrDSjeyl&confirm=t&uuid=58c6a8b0-883e-45c6-bf85-a4affb9033a9
# To: /content/pfcn_small.npz
# 100% 137M/137M [00:01<00:00, 130MB/s]

# %%
# !ls -al /content/pfcn_small.npz
# Out:
# -rw-r--r-- 1 root root 137288603 Nov 13  2020 /content/pfcn_small.npz

# %%
# pfcn_small.npz에서 train_images, test_images, train_mattes, test_mattes를 np array로 로드하세요.
pfcn_small = np.load('/content/pfcn_small.npz')

# %%
train_images = pfcn_small['train_images']
train_mattes = pfcn_small['train_mattes']
test_images = pfcn_small['test_images']
test_mattes = pfcn_small['test_mattes']

# %% [markdown]
# ### 문제 7. train_images에서 0이 아닌 값들을 출력해보세요.

# %%
# 하나의 이미지에 대한 모든 0이 아닌 값을 출력하는 코드를 작성하세요.
list(filter(lambda x:  x!=0, train_images[0].reshape(-1)))[:10]
# Out:
# [np.float64(0.2362745098039194),
#  np.float64(0.3480392156862709),
#  np.float64(0.6470588235294088),
#  np.float64(0.24509803921568626),
#  np.float64(0.3568627450980406),
#  np.float64(0.6558823529411772),
#  np.float64(0.2549019607843108),
#  np.float64(0.3647058823529383),
#  np.float64(0.6647058823529384),
#  np.float64(0.23725490196078006)]

# %%
train_images[train_images != 0][:10]
# Out:
# array([0.23627451, 0.34803922, 0.64705882, 0.24509804, 0.35686275,
#        0.65588235, 0.25490196, 0.36470588, 0.66470588, 0.2372549 ])

# %% [markdown]
# ### 문제 8. train_images의 dtype을 출력해보세요.

# %%
# dtype을 이용하여 이미지의 np array type을 확인해보세요.
train_images.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## Step 2. 전처리

# %% [markdown]
# ### 문제 9. images/mattes 이미지 데이터의 범위 확인

# %%
#  test_images, test_mattes의 shape과 dtype, 0이 아닌 숫자를 출력하는 코드를 작성하세요.
print(train_images.shape)
print(list(filter(lambda x: x != 0, train_images[0:100].reshape(-1)))[:10])
print(train_images.dtype)
print("-------------------")
print(test_images.shape)
print(list(filter(lambda x: x != 0, test_images[0:100].reshape(-1)))[:10])
print(test_images.dtype)
# Out:
# (1700, 100, 75, 3)
# [np.float64(0.2362745098039194), np.float64(0.3480392156862709), np.float64(0.6470588235294088), np.float64(0.24509803921568626), np.float64(0.3568627450980406), np.float64(0.6558823529411772), np.float64(0.2549019607843108), np.float64(0.3647058823529383), np.float64(0.6647058823529384), np.float64(0.23725490196078006)]
# float64
# -------------------
# (300, 100, 75, 3)
# [np.float64(0.5098039215686274), np.float64(0.6411764705882368), np.float64(0.6431372549019636), np.float64(0.5156862745098024), np.float64(0.6470588235294088), np.float64(0.649019607843133), np.float64(0.5382352941176594), np.float64(0.6558823529411887), np.float64(0.6637254901960906), np.float64(0.5284313725490188)]
# float64

# %%
print(train_images.shape)
print(train_images[train_images != 0][:10])
print(train_images.dtype)
print("-------------------")
print(test_images.shape)
print(test_images[test_images != 0][:10])
print(test_images.dtype)

# %% [markdown]
# ### 문제 10. images/mattes 이미지 데이터의 최소/최대값을 출력

# %%
# train/test 전체 데이터에서 각 images, mattes의 min, max를 출력하는 코드를 작성하세요.
print(train_images.max(), train_images.min())
print(test_images.max(), test_images.min())
# Out:
# 1.0 0.0
# 1.0 0.0

# %% [markdown]
# ### 문제 11. mattes의 shape을 (배치, 100, 75, 3)에서 (배치, 100, 75, 1)으로 변경하세요.

# %%
# (배치, 100, 75,3)의 흑백 shape을 (배치, 100, 75, 1)의 흑백 shape의 영역으로 축소하는 코드를 추가하세요.
from skimage import color
train_mattes = np.array( [color.rgb2gray(img).reshape((100, 75, 1)) for img in train_mattes] )
test_mattes = np.array( [color.rgb2gray(img).reshape((100, 75, 1)) for img in test_mattes] )
train_mattes.shape, test_mattes.shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/1413618218.py in <cell line: 0>()
#       1 # (배치, 100, 75,3)의 흑백 shape을 (배치, 100, 75, 1)의 흑백 shape의 영역으로 축소하는 코드를 추가하세요.
#       2 from skimage import color
# ----> 3 train_mattes = np.array( [color.rgb2gray(img).reshape((100, 75, 1)) for img in train_mattes] )
#       4 test_mattes = np.array( [color.rgb2gray(img).reshape((100, 75, 1)) for img in test_mattes] )
#       5 train_mattes.shape, test_mattes.shape
#
# /usr/local/lib/python3.12/dist-packages/skimage/_shared/utils.py in fixed_func(*args, **kwargs)
#     443
#     444             if channel_axis is None:
# --> 445                 return func(*args, **kwargs)
#     446
#     447             # TODO: convert scalars to a tuple in anticipation of eventually
#
# /usr/local/lib/python3.12/dist-packages/skimage/color/colorconv.py in rgb2gray(rgb, channel_axis)
#     980     >>> img_gray = rgb2gray(img)
#     981     """
# --> 982     rgb = _prepare_colorarray(rgb)
#     983     coeffs = np.array([0.2125, 0.7154, 0.0721], dtype=rgb.dtype)
#     984     return rgb @ coeffs
#
# /usr/local/lib/python3.12/dist-packages/skimage/color/colorconv.py in _prepare_colorarray(arr, force_copy, channel_axis)
#     168             f'got {arr.shape}'
#     169         )
# --> 170         raise ValueError(msg)
#     171
#     172     float_dtype = _supported_float_type(arr.dtype)
#
# ValueError: the input array must have size 3 along `channel_axis`, got (100, 75)

# %% [markdown]
# ## Step 3. 시각화 방법

# %% [markdown]
# ### 문제 12. train_image의 이미지를 5장 획득하여 (5, 100, 75, 3)의 shape을 출력하세요.

# %%
# (배치, 100, 75, 3)인 train_images에서 (5, 100, 75, 3)을 획득하는 코드를 작성하세요.
train_images[:5].shape
# Out:
# (5, 100, 75, 3)

# %% [markdown]
# ### 문제 13. 획득한 5장의 의미지를 (100, 75 * 5, 3)의 shape으로 변경해보세요.

# %%
# np.hstack은 height 방향의 배열을 풀어서 width 방향으로 연결해줍니다.
# 해당 기능을 쓰면 (height, image_height, image_width, color)의 shape을 (image_height, image_width * height, color)으로 바꿔 줄 수 있습니다.
# 코드를 작성해보세요.
np.hstack(train_images[:5]).shape
# Out:
# (100, 375, 3)

# %%
# transpose는 tensor의 axis를 섞는 기능을 합니다.
# 해당 기능을 이용해서 (100, 375, 3)을 작성하는 코드를 작성해보세요.
train_images[:5].transpose([1, 0, 2, 3]).reshape((100, -1 ,3)).shape
# Out:
# (100, 375, 3)

# %% [markdown]
# ### 문제 14. (100, 375, 3)이 된 tensor를 plt로 출력해보세요.

# %%
# (28, 140, 3)의 이미지를 plt로 출력해보세요.
plt.imshow(train_images[:5].transpose([1, 0, 2, 3]).reshape((100, -1 ,3)))
plt.show()

# %% [markdown]
# ### 문제 15. mettes도 (100, 375)으로 plt로 출력해보세요.

# %%
# (28, 140, 1)의 이미지를 plt로 출력해보세요.
plt.imshow(train_mattes[:5].transpose([1, 0, 2, 3]).reshape((100, -1)), cmap="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/1487843810.py in <cell line: 0>()
#       1 # (28, 140, 1)의 이미지를 plt로 출력해보세요.
# ----> 2 plt.imshow(train_mattes[:5].transpose([1, 0, 2, 3]).reshape((100, -1)), cmap="gray")
#       3 plt.show()
#
# ValueError: axes don't match array

# %% [markdown]
# ## Step 4. AE 모델링

# %% [markdown]
# ### 문제 16. 해당 학습셋을 처리하는 이미지 segmentation 모델을 작성하세요.

# %%
# input (100, 75, 3), output (100, 75, 1)을 처리할 수 있는 모래시계 모양의 모델을 작성하세요.
from keras.layers import Dense, Input, Conv2D, UpSampling2D, Flatten, Reshape
from keras.models import Model

def ae_like():
  inputs = Input((100, 75, 3))
  x = Conv2D(32, 3, 2, activation='relu', padding='same')(inputs)
  x = Conv2D(64, 3, 2, activation='relu', padding='same')(x)
  x = Conv2D(128, 3, 2, activation='relu', padding='same')(x)
  x = Flatten()(x)
  latent = Dense(10)(x)

  x = Dense((13 * 10 * 128))(latent)
  x = Reshape((13, 10, 128))(x)

  x = UpSampling2D(size = (2,2))(x)
  x = Conv2D(128, (2,2), (1,1), activation='relu', padding='valid')(x)

  x = UpSampling2D(size = (2,2))(x)
  x = Conv2D(64, (1,1), (1,1), activation='relu', padding='valid')(x)

  x = UpSampling2D(size = (2,2))(x)
  x = Conv2D(32, (1,2), (1,1), activation='relu', padding='valid')(x)

  x = Conv2D(1, (1,1), (1,1), activation='sigmoid')(x)


  model = Model(inputs, x)
  return model

# %% [markdown]
# ### 문제 17. 모델을 할당 받고 서머리를 출력해보세요.

# %%
# ae_like() 모델을 할당 받고 서머리를 출력하는 코드를 작성하세요.
model = ae_like()
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 100, 75, 3)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 50, 38, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 25, 19, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 13, 10, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 16640)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │       166,410 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16640)          │       183,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ reshape (Reshape)               │ (None, 13, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 26, 20, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 25, 19, 128)    │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 50, 38, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 50, 38, 64)     │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_2 (UpSampling2D)  │ (None, 100, 76, 64)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 100, 75, 32)    │         4,128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 100, 75, 1)     │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 520,779 (1.99 MB)
#  Trainable params: 520,779 (1.99 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### 문제 18. 만든 모델에 로스와 옵티마이저, 메트릭을 설정하세요.

# %%
# 만든 모델에 loss는 mse, optimizer는 adam 매트릭은 accuracy으로 설정하는 코드를 작성하세요.
model.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ### 문제 19. 만든 모델에 train_images를 학습시켜 보세요.

# %%
# train_images 학습시키고 25 epochs을 돌리고 그 진행 사항을 hist에 저장하는 코드를 작성하세요.
hist = model.fit(train_images, train_mattes, validation_data=(test_images, test_mattes), epochs=25, verbose=1)
# Out:
# Epoch 1/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 18s 197ms/step - accuracy: 0.7483 - loss: 0.1400 - val_accuracy: 0.7623 - val_loss: 0.1275
# Epoch 2/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 6s 19ms/step - accuracy: 0.7681 - loss: 0.1229 - val_accuracy: 0.7747 - val_loss: 0.1139
# Epoch 3/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.7929 - loss: 0.1042 - val_accuracy: 0.8042 - val_loss: 0.0940
# Epoch 4/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8159 - loss: 0.0874 - val_accuracy: 0.8201 - val_loss: 0.0822
# Epoch 5/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8269 - loss: 0.0789 - val_accuracy: 0.8219 - val_loss: 0.0814
# Epoch 6/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8371 - loss: 0.0710 - val_accuracy: 0.8298 - val_loss: 0.0743
# Epoch 7/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8474 - loss: 0.0634 - val_accuracy: 0.8358 - val_loss: 0.0700
# Epoch 8/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8549 - loss: 0.0578 - val_accuracy: 0.8358 - val_loss: 0.0704
# Epoch 9/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8621 - loss: 0.0523 - val_accuracy: 0.8405 - val_loss: 0.0675
# Epoch 10/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8692 - loss: 0.0466 - val_accuracy: 0.8407 - val_loss: 0.0672
# Epoch 11/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8741 - loss: 0.0426 - val_accuracy: 0.8409 - val_loss: 0.0679
# Epoch 12/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8787 - loss: 0.0388 - val_accuracy: 0.8423 - val_loss: 0.0675
# Epoch 13/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8810 - loss: 0.0368 - val_accuracy: 0.8428 - val_loss: 0.0673
# Epoch 14/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8859 - loss: 0.0323 - val_accuracy: 0.8418 - val_loss: 0.0690
# Epoch 15/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8886 - loss: 0.0300 - val_accuracy: 0.8399 - val_loss: 0.0710
# Epoch 16/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8903 - loss: 0.0283 - val_accuracy: 0.8417 - val_loss: 0.0706
# Epoch 17/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8924 - loss: 0.0263 - val_accuracy: 0.8412 - val_loss: 0.0710
# Epoch 18/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.8937 - loss: 0.0252 - val_accuracy: 0.8425 - val_loss: 0.0719
# Epoch 19/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8945 - loss: 0.0244 - val_accuracy: 0.8418 - val_loss: 0.0723
# Epoch 20/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8953 - loss: 0.0237 - val_accuracy: 0.8411 - val_loss: 0.0723
# Epoch 21/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8963 - loss: 0.0226 - val_accuracy: 0.8418 - val_loss: 0.0728
# Epoch 22/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8972 - loss: 0.0218 - val_accuracy: 0.8408 - val_loss: 0.0740
# Epoch 23/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8971 - loss: 0.0218 - val_accuracy: 0.8418 - val_loss: 0.0726
# Epoch 24/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8979 - loss: 0.0210 - val_accuracy: 0.8423 - val_loss: 0.0728
# Epoch 25/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.8989 - loss: 0.0199 - val_accuracy: 0.8421 - val_loss: 0.0734

# %% [markdown]
# ### 문제 20. 학습 진행 사항을 plt으로 출력하세요.

# %%
# hist의 accuracy plt의 plot을 이용하여 출력하는 코드를 작성하세요.
plt.plot(hist.history['accuracy'], label = "accuracy")
plt.plot(hist.history['loss'], label = "loss")
plt.plot(hist.history['val_accuracy'], label = "val_accuracy")
plt.plot(hist.history['val_loss'], label = "val_loss")
plt.legend(loc = "uppder left")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/1904316195.py in <cell line: 0>()
#       4 plt.plot(hist.history['val_accuracy'], label = "val_accuracy")
#       5 plt.plot(hist.history['val_loss'], label = "val_loss")
# ----> 6 plt.legend(loc = "uppder left")
#       7 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    3617 @_copy_docstring_and_deprecators(Axes.legend)
#    3618 def legend(*args, **kwargs) -> Legend:
# -> 3619     return gca().legend(*args, **kwargs)
#    3620
#    3621
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     335         """
#     336         handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
# --> 337         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     338         self.legend_._remove_method = self._remove_legend
#     339         return self.legend_
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/legend.py in __init__(self, parent, handles, labels, loc, numpoints, markerscale, markerfirst, reverse, scatterpoints, scatteryoffsets, prop, fontsize, labelcolor, borderpad, labelspacing, handlelength, handleheight, handletextpad, borderaxespad, columnspacing, ncols, mode, fancybox, shadow, title, title_fontsize, framealpha, edgecolor, facecolor, bbox_to_anchor, bbox_transform, frameon, handler_map, title_fontproperties, alignment, ncol, draggable)
#     550
#     551         # Set legend location
# --> 552         self.set_loc(loc)
#     553
#     554         # figure out title font properties:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/legend.py in set_loc(self, loc)
#     668                     loc = locs[0] + ' ' + locs[1]
#     669             # check that loc is in acceptable strings
# --> 670             loc = _api.check_getitem(self.codes, loc=loc)
#     671         elif np.iterable(loc):
#     672             # coerce iterable into tuple
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/__init__.py in check_getitem(mapping, **kwargs)
#     182         return mapping[v]
#     183     except KeyError:
# --> 184         raise ValueError(
#     185             f"{v!r} is not a valid value for {k}; supported values are "
#     186             f"{', '.join(map(repr, mapping))}") from None
#
# ValueError: 'uppder left' is not a valid value for loc; supported values are 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'

# %% [markdown]
# ## Step 5. 결과 확인

# %% [markdown]
# ### 문제 21. 완성된 모델에서 test_image를 1장 넣고 결과를 res 변수에 저정하세요.

# %%
# 모델에 test_mages 중 1장을 넣고 결과를 받는 코드를 작성하세요.
res = model.predict( test_images[0:1] )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 956ms/step

# %% [markdown]
# ### 문제 22. res, test_mattes[1]를 width 방향으로 결합하여 plt로 출력하세요.

# %%
# res, test_mattes[1]를 width 방향으로 결합하여 (100, 75 * 3, 1) 의 이미지를 만들어 plt로 출력하는 코드를 작성하세요.

plt.imshow( np.concatenate([res[0], test_mattes[0]]).reshape((2, -1, 75, 1)).transpose([1, 0, 2, 3]).reshape((100, -1)), cmap="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/2378889808.py in <cell line: 0>()
#       1 # res, test_mattes[1]를 width 방향으로 결합하여 (100, 75 * 3, 1) 의 이미지를 만들어 plt로 출력하는 코드를 작성하세요.
#       2
# ----> 3 plt.imshow( np.concatenate([res[0], test_mattes[0]]).reshape((2, -1, 75, 1)).transpose([1, 0, 2, 3]).reshape((100, -1)), cmap="gray")
#       4 plt.show()
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 3 dimension(s) and the array at index 1 has 2 dimension(s)

# %% [markdown]
# ### 문제 23. res에 0.5의 값을 기준으로 0과 1로 2원화 시키고 다시 문제 22처럼 출력해보세요.

# %%
# res를 0.5기준으로 0,1의 값으로 이원화 시킨 뒤 문제 22처럼 출력하는 코드를 작성하세요.
plt.imshow( np.concatenate([(res[0] > 0.5).astype(np.float64), test_mattes[0]]).reshape((2, -1, 75, 1)).transpose([1, 0, 2, 3]).reshape((100, -1)), cmap="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/3144879180.py in <cell line: 0>()
#       1 # res를 0.5기준으로 0,1의 값으로 이원화 시킨 뒤 문제 22처럼 출력하는 코드를 작성하세요.
# ----> 2 plt.imshow( np.concatenate([(res[0] > 0.5).astype(np.float64), test_mattes[0]]).reshape((2, -1, 75, 1)).transpose([1, 0, 2, 3]).reshape((100, -1)), cmap="gray")
#       3 plt.show()
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 3 dimension(s) and the array at index 1 has 2 dimension(s)

# %% [markdown]
# ### 문제 24. 5장의 test_images를 모델에 넣은 뒤 결과를 문제 22 방식으로 비교하세요.

# %%
# 5장의 이미지를 모델에 넣고 결과를 22번과 같은 방식으로 비교하는 코드를 작성하세요

five = (model.predict(test_images[:5]) > 0.5).astype(np.float64)
plt.imshow( np.concatenate([five , test_mattes[:5]], axis=2).transpose((1, 0, 2, 3)).reshape(100, -1) , cmap="gray")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/3798694085.py in <cell line: 0>()
#       2
#       3 five = (model.predict(test_images[:5]) > 0.5).astype(np.float64)
# ----> 4 plt.imshow( np.concatenate([five , test_mattes[:5]], axis=2).transpose((1, 0, 2, 3)).reshape(100, -1) , cmap="gray")
#       5 plt.show()
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 4 dimension(s) and the array at index 1 has 3 dimension(s)

# %%
plt.imshow(test_images[:5].transpose((1, 0, 2, 3)).reshape((100, -1, 3)))
plt.show()

# %% [markdown]
# ### 문제 25. test_images[1]과 res를 곱한뒤 plt에 출력해보세요.

# %%
# 예측 이미지와 원본이미지를 곱하여 배경을 지워보세요

plt.imshow ( five[2].reshape((100, 75, 1)) * test_images[2]  )
plt.show()

# %% [markdown]
# ## Step 6. U-net 모델링

# %% [markdown]
# ### 문제 26. 해당 학습셋을 처리하는 이미지 segmentation 모델을 작성하세요.

# %%
# input (100, 75, 3), output (100, 75, 1)을 처리할 수 있는 모래시계 모양의 모델을 작성하세요.
from keras.layers import Dense, Input, Conv2D, Conv2DTranspose, Flatten, Reshape
from keras.models import Model
from keras.layers import BatchNormalization, Dropout, Activation, MaxPool2D, concatenate

def conv2d_block(x, channel):
  x = Conv2D(channel, 3, padding="same")(x)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)

  x = Conv2D(channel, 3, padding="same")(x)
  x = BatchNormalization()(x)
  x = Activation("relu")(x)
  return x

def unet_like():
  inputs = Input((100, 75, 3))

  c1 = conv2d_block(inputs, 16)
  p1 = MaxPool2D((2,2))(c1)
  p1 = Dropout(0.1)(p1)

  c2 = conv2d_block(p1, 32)
  p2 = MaxPool2D((2,2))(c2)
  p2 = Dropout(0.1)(p2)

  c3 = conv2d_block(p2, 64)
  p3 = MaxPool2D((2,2))(c3)
  p3 = Dropout(0.1)(p3)

  c4 = conv2d_block(p3, 128)
  p4 = MaxPool2D((2,2))(c4)
  p4 = Dropout(0.1)(p4)

  c5 = conv2d_block(p4, 256)

  u6 = Conv2DTranspose(128, 2, 2, output_padding=(0,1))(c5)
  u6 = concatenate([u6, c4])
  u6 = Dropout(0.1)(u6)
  c6 = conv2d_block(u6, 128)

  u7 = Conv2DTranspose(64, 2, 2, output_padding=(1,0))(c6)
  u7 = concatenate([u7, c3])
  u7 = Dropout(0.1)(u7)
  c7 = conv2d_block(u7, 64)

  u8 = Conv2DTranspose(32, 2, 2, output_padding=(0,1))(c7)
  u8 = concatenate([u8, c2])
  u8 = Dropout(0.1)(u8)
  c8 = conv2d_block(u8, 32)

  u9 = Conv2DTranspose(16, 2, 2, output_padding=(0,1))(c8)
  u9 = concatenate([u9, c1])
  u9 = Dropout(0.1)(u9)
  c9 = conv2d_block(u9, 16)

  outputs = Conv2D(1, (1,1), activation="sigmoid")(c9)

  model = Model(inputs, outputs)
  return model

# %% [markdown]
# ### 문제 27. 모델을 할당 받고 서머리를 출력해보세요.

# %%
# unet_like() 모델을 할당 받고 서머리를 출력하는 코드를 작성하세요.
model = unet_like()
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 100, 75,   │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 100, 75,   │        448 │ input_layer_1[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 100, 75,   │         64 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 100, 75,   │      2,320 │ activation[0][0]  │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 50, 37,    │          0 │ activation_1[0][… │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 50, 37,    │          0 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 50, 37,    │      4,640 │ dropout[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 50, 37,    │      9,248 │ activation_2[0][… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 25, 18,    │          0 │ activation_3[0][… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 25, 18,    │          0 │ max_pooling2d_1[… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 25, 18,    │     18,496 │ dropout_1[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_4        │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 25, 18,    │     36,928 │ activation_4[0][… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_5        │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 12, 9, 64) │          0 │ activation_5[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_2 (Dropout) │ (None, 12, 9, 64) │          0 │ max_pooling2d_2[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 12, 9,     │     73,856 │ dropout_2[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_6        │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 12, 9,     │    147,584 │ activation_6[0][… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 6, 4, 128) │          0 │ activation_7[0][… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_3 (Dropout) │ (None, 6, 4, 128) │          0 │ max_pooling2d_3[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 6, 4, 256) │    295,168 │ dropout_3[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 4, 256) │      1,024 │ conv2d_15[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 6, 4, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 6, 4, 256) │    590,080 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 6, 4, 256) │      1,024 │ conv2d_16[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_9        │ (None, 6, 4, 256) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 12, 9,     │    131,200 │ activation_9[0][… │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 12, 9,     │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_4 (Dropout) │ (None, 12, 9,     │          0 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 12, 9,     │    295,040 │ dropout_4[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_17[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_10       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 12, 9,     │    147,584 │ activation_10[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 12, 9,     │        512 │ conv2d_18[0][0]   │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_11       │ (None, 12, 9,     │          0 │ batch_normalizat… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 25, 18,    │     32,832 │ activation_11[0]… │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 25, 18,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ activation_5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 25, 18,    │          0 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 25, 18,    │     73,792 │ dropout_5[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_19[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_12       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 25, 18,    │     36,928 │ activation_12[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 25, 18,    │        256 │ conv2d_20[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_13       │ (None, 25, 18,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 50, 37,    │      8,224 │ activation_13[0]… │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 50, 37,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 50, 37,    │          0 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 50, 37,    │     18,464 │ dropout_6[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_21[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_14       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_22 (Conv2D)  │ (None, 50, 37,    │      9,248 │ activation_14[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 50, 37,    │        128 │ conv2d_22[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_15       │ (None, 50, 37,    │          0 │ batch_normalizat… │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 100, 75,   │      2,064 │ activation_15[0]… │
# │ (Conv2DTranspose)   │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 100, 75,   │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 32)               │            │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 100, 75,   │          0 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_23 (Conv2D)  │ (None, 100, 75,   │      4,624 │ dropout_7[0][0]   │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_23[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_16       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_24 (Conv2D)  │ (None, 100, 75,   │      2,320 │ activation_16[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 100, 75,   │         64 │ conv2d_24[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_17       │ (None, 100, 75,   │          0 │ batch_normalizat… │
# │ (Activation)        │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_25 (Conv2D)  │ (None, 100, 75,   │         17 │ activation_17[0]… │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 1,946,993 (7.43 MB)
#  Trainable params: 1,944,049 (7.42 MB)
#  Non-trainable params: 2,944 (11.50 KB)

# %% [markdown]
# ### 문제 28. 만든 모델에 로스와 옵티마이저, 메트릭을 설정하세요.

# %%
# 만든 모델에 loss는 mse, optimizer는 adam 매트릭은 accuracy으로 설정하는 코드를 작성하세요.
model.compile(loss="mse", optimizer="adam", metrics=["accuracy"])

# %% [markdown]
# ### 문제 29. 만든 모델에 train_noisy_images를 학습시켜 보세요.

# %%
# train_images 학습시키고 25 epochs을 돌리고 그 진행 사항을 hist에 저장하는 코드를 작성하세요.
hist = model.fit(train_images, train_mattes, validation_data=(test_images, test_mattes), epochs=25, verbose=1)
# Out:
# Epoch 1/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 57s 474ms/step - accuracy: 0.7148 - loss: 0.1582 - val_accuracy: 0.7524 - val_loss: 0.1495
# Epoch 2/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 39s 42ms/step - accuracy: 0.8417 - loss: 0.0724 - val_accuracy: 0.7783 - val_loss: 0.1169
# Epoch 3/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8586 - loss: 0.0555 - val_accuracy: 0.7461 - val_loss: 0.1394
# Epoch 4/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.8664 - loss: 0.0471 - val_accuracy: 0.7453 - val_loss: 0.1485
# Epoch 5/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8742 - loss: 0.0398 - val_accuracy: 0.7142 - val_loss: 0.1746
# Epoch 6/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8795 - loss: 0.0345 - val_accuracy: 0.8170 - val_loss: 0.0867
# Epoch 7/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8798 - loss: 0.0336 - val_accuracy: 0.8578 - val_loss: 0.0517
# Epoch 8/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8838 - loss: 0.0299 - val_accuracy: 0.8551 - val_loss: 0.0549
# Epoch 9/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8870 - loss: 0.0267 - val_accuracy: 0.8763 - val_loss: 0.0355
# Epoch 10/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8890 - loss: 0.0250 - val_accuracy: 0.8655 - val_loss: 0.0454
# Epoch 11/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8915 - loss: 0.0225 - val_accuracy: 0.8768 - val_loss: 0.0336
# Epoch 12/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8892 - loss: 0.0241 - val_accuracy: 0.8810 - val_loss: 0.0298
# Epoch 13/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8929 - loss: 0.0208 - val_accuracy: 0.8763 - val_loss: 0.0348
# Epoch 14/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8946 - loss: 0.0192 - val_accuracy: 0.8836 - val_loss: 0.0281
# Epoch 15/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 42ms/step - accuracy: 0.8958 - loss: 0.0177 - val_accuracy: 0.8788 - val_loss: 0.0328
# Epoch 16/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8967 - loss: 0.0169 - val_accuracy: 0.8852 - val_loss: 0.0256
# Epoch 17/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.8978 - loss: 0.0159 - val_accuracy: 0.8843 - val_loss: 0.0271
# Epoch 18/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8961 - loss: 0.0173 - val_accuracy: 0.8845 - val_loss: 0.0268
# Epoch 19/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8972 - loss: 0.0161 - val_accuracy: 0.8847 - val_loss: 0.0263
# Epoch 20/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.8988 - loss: 0.0145 - val_accuracy: 0.8835 - val_loss: 0.0263
# Epoch 21/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - accuracy: 0.8986 - loss: 0.0147 - val_accuracy: 0.8827 - val_loss: 0.0274
# Epoch 22/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8953 - loss: 0.0176 - val_accuracy: 0.8866 - val_loss: 0.0241
# Epoch 23/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8989 - loss: 0.0143 - val_accuracy: 0.8790 - val_loss: 0.0315
# Epoch 24/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.8992 - loss: 0.0139 - val_accuracy: 0.8873 - val_loss: 0.0231
# Epoch 25/25
# 54/54 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step - accuracy: 0.9006 - loss: 0.0126 - val_accuracy: 0.8880 - val_loss: 0.0223

# %% [markdown]
# ### 문제 30. 학습 진행 사항을 plt으로 출력하세요.

# %%
# hist의 accuracy plt의 plot을 이용하여 출력하는 코드를 작성하세요.
plt.plot(hist.history['accuracy'], label = "accuracy")
plt.plot(hist.history['loss'], label = "loss")
plt.plot(hist.history['val_accuracy'], label = "val_accuracy")
plt.plot(hist.history['val_loss'], label = "val_loss")
plt.legend(loc = "uppder left")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/1904316195.py in <cell line: 0>()
#       4 plt.plot(hist.history['val_accuracy'], label = "val_accuracy")
#       5 plt.plot(hist.history['val_loss'], label = "val_loss")
# ----> 6 plt.legend(loc = "uppder left")
#       7 plt.show()
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py in legend(*args, **kwargs)
#    3617 @_copy_docstring_and_deprecators(Axes.legend)
#    3618 def legend(*args, **kwargs) -> Legend:
# -> 3619     return gca().legend(*args, **kwargs)
#    3620
#    3621
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     335         """
#     336         handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
# --> 337         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     338         self.legend_._remove_method = self._remove_legend
#     339         return self.legend_
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/legend.py in __init__(self, parent, handles, labels, loc, numpoints, markerscale, markerfirst, reverse, scatterpoints, scatteryoffsets, prop, fontsize, labelcolor, borderpad, labelspacing, handlelength, handleheight, handletextpad, borderaxespad, columnspacing, ncols, mode, fancybox, shadow, title, title_fontsize, framealpha, edgecolor, facecolor, bbox_to_anchor, bbox_transform, frameon, handler_map, title_fontproperties, alignment, ncol, draggable)
#     550
#     551         # Set legend location
# --> 552         self.set_loc(loc)
#     553
#     554         # figure out title font properties:
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/legend.py in set_loc(self, loc)
#     668                     loc = locs[0] + ' ' + locs[1]
#     669             # check that loc is in acceptable strings
# --> 670             loc = _api.check_getitem(self.codes, loc=loc)
#     671         elif np.iterable(loc):
#     672             # coerce iterable into tuple
#
# /usr/local/lib/python3.12/dist-packages/matplotlib/_api/__init__.py in check_getitem(mapping, **kwargs)
#     182         return mapping[v]
#     183     except KeyError:
# --> 184         raise ValueError(
#     185             f"{v!r} is not a valid value for {k}; supported values are "
#     186             f"{', '.join(map(repr, mapping))}") from None
#
# ValueError: 'uppder left' is not a valid value for loc; supported values are 'best', 'upper right', 'upper left', 'lower left', 'lower right', 'right', 'center left', 'center right', 'lower center', 'upper center', 'center'

# %% [markdown]
# ## Step 7. 결과 확인

# %% [markdown]
# ### 문제 31. 완성된 모델에서 test_image를 1장 넣고 결과를 res 변수에 저정하세요.

# %%
# 모델에 test_mages 중 1장을 넣고 결과를 받는 코드를 작성하세요.
res = model.predict( test_images[2:3] )
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step

# %% [markdown]
# ### 문제 32. test_images[1], test_mattes[1]를 width 방향으로 결합하여 plt로 출력하세요.

# %%
# test_mattes[1]를 width 방향으로 결합하여 (100, 75 * 3, 1) 의 이미지를 만들어 plt로 출력하는 코드를 작성하세요.
imgs = np.concatenate([res.reshape((100, 75, 1)), test_mattes[2]]).reshape((2, -1, 75, 1)).transpose((1,0, 2, 3)).reshape((100, -1))
plt.imshow(imgs, cmap="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/4174304104.py in <cell line: 0>()
#       1 # test_mattes[1]를 width 방향으로 결합하여 (100, 75 * 3, 1) 의 이미지를 만들어 plt로 출력하는 코드를 작성하세요.
# ----> 2 imgs = np.concatenate([res.reshape((100, 75, 1)), test_mattes[2]]).reshape((2, -1, 75, 1)).transpose((1,0, 2, 3)).reshape((100, -1))
#       3 plt.imshow(imgs, cmap="gray")
#       4 plt.show()
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 3 dimension(s) and the array at index 1 has 2 dimension(s)

# %% [markdown]
# ### 문제 33. res에 0.5의 값을 기준으로 0과 1로 2원화 시키고 다시 문제 32처럼 출력해보세요.

# %%
# res를 0.5기준으로 0,1의 값으로 이원화 시킨 뒤 문제 32처럼 출력하는 코드를 작성하세요.
imgs = np.concatenate([(res > 0.5).astype(np.float64).reshape((100, 75, 1)), test_mattes[2] ]).reshape((2, -1, 75, 1)).transpose((1,0, 2, 3)).reshape((100, -1))
plt.imshow(imgs, cmap="gray")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/2795790914.py in <cell line: 0>()
#       1 # res를 0.5기준으로 0,1의 값으로 이원화 시킨 뒤 문제 32처럼 출력하는 코드를 작성하세요.
# ----> 2 imgs = np.concatenate([(res > 0.5).astype(np.float64).reshape((100, 75, 1)), test_mattes[2] ]).reshape((2, -1, 75, 1)).transpose((1,0, 2, 3)).reshape((100, -1))
#       3 plt.imshow(imgs, cmap="gray")
#       4 plt.show()
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 3 dimension(s) and the array at index 1 has 2 dimension(s)

# %% [markdown]
# ### 문제 34. 5장의 test_images를 모델에 넣은 뒤 결과를 문제 32 방식으로 비교하세요.

# %%
# 5장의 이미지를 모델에 넣고 결과를 32번과 같은 방식으로 비교하는 코드를 작성하세요
five = (model.predict(test_images[:5]) > 0.5).astype(np.float64)
plt.imshow( np.concatenate([five , test_mattes[:5]], axis=2).transpose((1, 0, 2, 3)).reshape(100, -1) , cmap="gray")
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/2125800512.py in <cell line: 0>()
#       1 # 5장의 이미지를 모델에 넣고 결과를 32번과 같은 방식으로 비교하는 코드를 작성하세요
#       2 five = (model.predict(test_images[:5]) > 0.5).astype(np.float64)
# ----> 3 plt.imshow( np.concatenate([five , test_mattes[:5]], axis=2).transpose((1, 0, 2, 3)).reshape(100, -1) , cmap="gray")
#       4 plt.show()
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 4 dimension(s) and the array at index 1 has 3 dimension(s)

# %%
plt.imshow(test_images[:5].transpose((1,0, 2, 3)).reshape((100, -1, 3)))
plt.show()

# %% [markdown]
# ### 문제 35. test_images[1]과 res를 곱한뒤 plt에 출력해보세요.

# %%
# 예측 이미지와 원본이미지를 곱하여 배경을 지워보세요
plt.imshow(test_images[4] * test_mattes[4].reshape((100, 75 ,1)))
plt.show()

# %%
plt.imshow(test_images[4] * model.predict(test_images[4:5]).reshape((100, 75 ,1)))
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step

# %% [markdown]
# ## Step 8. 모델 저장 및 로드, 다운

# %% [markdown]
# ### 문제 36. 모델을 저장하세요.

# %%
# 모델을 저장하는 코드를 작성하세요.
model.save("./lecture003.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# !ls -al /content

# %% [markdown]
# ### 문제 37. 모델 파일을 새로운 모델에 로드하세요.

# %%
# 모델을 로드하는 코드를 작성하세요.
new_model = tf.keras.models.load_model("./lecture003.h5")
new_model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1380/2686603897.py in <cell line: 0>()
#       1 # 모델을 로드하는 코드를 작성하세요.
# ----> 2 new_model = tf.keras.models.load_model("./lecture003.h5")
#       3 new_model.summary()
#
# /usr/local/lib/python3.12/dist-packages/keras/src/saving/saving_api.py in load_model(filepath, custom_objects, compile, safe_mode)
#     194         )
#     195     if str(filepath).endswith((".h5", ".hdf5")):
# --> 196         return legacy_h5_format.load_model_from_hdf5(
#     197             filepath,
#     198             custom_objects=custom_objects,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/saving/legacy_h5_format.py in load_model_from_hdf5(filepath, custom_objects, compile, safe_mode)
#     135         safe_mode_scope = serialization_lib.SafeModeScope(safe_mode)
#     136         with legacy_scope, safe_mode_scope:
# --> 137             model = saving_utils.model_from_config(
#     138                 model_config, custom_objects=custom_objects
#     139             )
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/saving/saving_utils.py in model_from_config(config, custom_objects)
#      81             config["config"]["function"] = function_dict
#      82
# ---> 83     return serialization.deserialize_keras_object(
#      84         config,
#      85         module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/legacy/saving/serialization.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     486
#     487             if "custom_objects" in arg_spec.args:
# --> 488                 deserialized_obj = cls.from_config(
#     489                     cls_config,
#     490                     custom_objects={
#
# /usr/local/lib/python3.12/dist-packages/keras/src/models/model.py in from_config(cls, config, custom_objects)
#     821             from keras.src.models.functional import functional_from_config
#     822
# --> 823             return functional_from_config(
#     824                 cls, config, custom_objects=custom_objects
#     825             )
#
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py in functional_from_config(cls, config, custom_objects)
#     578                     node_data = node_data_list[node_index]
#     579                     try:
# --> 580                         process_node(layer, node_data)
#     581
#     582                     # If the node does not have all inbound layers
#
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py in process_node(layer, node_data)
#     508         # Call layer on its inputs, thus creating the node
#     509         # and building the layer if needed.
# --> 510         layer(*args, **kwargs)
#     511
#     512     def process_layer(layer_data):
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/merging/concatenate.py in build(self, input_shape)
#      97                 )
#      98                 if len(unique_dims) > 1:
# ---> 99                     raise ValueError(err_msg)
#     100
#     101     def _merge_function(self, inputs):
#
# ValueError: A `Concatenate` layer requires inputs with matching shapes except for the concatenation axis. Received: input_shape=[(None, 12, 8, 128), (None, 12, 9, 128)]

# %% [markdown]
# ### 문제 38. 로드한 모델을 test 데이터로 평가해보세요.

# %%
# 로드한 모델을 test 데이터로 평가해보세요.
loss, acc = model.evaluate(test_images, test_mattes, verbose=1)
print(loss, acc)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8880 - loss: 0.0223
# 0.022269079461693764 0.8880462646484375

# %%
loss, acc = new_model.evaluate(test_images, test_mattes, verbose=1)
print(loss, acc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1380/2607371998.py in <cell line: 0>()
# ----> 1 loss, acc = new_model.evaluate(test_images, test_mattes, verbose=1)
#       2 print(loss, acc)
#
# NameError: name 'new_model' is not defined

# %% [markdown]
# ### 문제 39. 모델을 내 컴퓨터에 저장해보세요

# %%
# 모델을 내 컴퓨터에 저장해보세요.
from google.colab import files
files.download("./lecture003.h5")
